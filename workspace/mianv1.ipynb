# %%
from ELTE import readRDF
import seaborn as sns
import matplotlib.pyplot as plt

# %%
exampleRDF = readRDF("rdf.dat")

# %%
plt.title("Example Radial Distribution Function of Oxygens")
sns.lineplot(data = exampleRDF,x = "binEdge",y = "rdf")
# Out:
# <AxesSubplot:title={'center':'Example Radial Distribution Function of Oxygens'}, xlabel='binEdge', ylabel='rdf'>
